# %% [markdown]
# # Aviation Accidents Analysis
#
# You are part of a consulting firm that is tasked to do an analysis of commercial and passenger jet airline safety. The client (an airline/airplane insurer) is interested in knowing what types of aircraft (makes/models) exhibit low rates of total destruction and low likelihood of fatal or serious passenger injuries in the event of an accident. They are also interested in any general variables/conditions that might be at play. Your analysis will be based off of aviation accident data accumulated from the years 1948-2023.
#
# Our client is only interested in airplane makes/models that are professional builds and could potentially still be active. Assume a max lifetime of 40 years for a make/model retirement and make sure to filter your data accordingly (i.e. from 1983 onwards). They would also like separate recommendations for small aircraft vs. larger passenger models. **In addition, make sure that claims that you make are statistically robust and that you have enough samples when making comparisons between groups.**
#
#
# In this summative assessment you will demonstrate your ability to:
# - **Use Pandas to load, inspect, and clean the dataset appropriately.**
# - **Transform relevant columns to create measures that address the problem at hand.**
# - conduct EDA: visualization and statistical measures to systematically understand the structure of the data
# - recommend a set of airplanes and makes conforming to the client's request and identify at least *two* factors contributing to airplane safety. You must provide supporting evidence (visuals, summary statistics, tables) for each claim you make.

# %% [markdown]
# ### Make relevant library imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Loading and Inspection

# %% [markdown]
# ### Load in data from the relevant directory and inspect the dataframe.
# - inspect NaNs, datatypes, and summary statistics

# %%
# Load the dataset
df = pd.read_csv('AviationData.csv', encoding='latin-1', low_memory=False)

# 1. Quick look at the first few rows to see what we're working with
display(df.head())

# 2. Inspect datatypes and total rows/columns
print("\n--- DATATYPES & INFO ---")
df.info()

# 3. Check for NaNs (Missing Values) to see how messy this is
print("\n--- MISSING VALUES ---")
display(df.isna().sum())

# 4. Summary Statistics (include='all' so we get text columns too)
print("\n--- SUMMARY STATISTICS ---")
display(df.describe(include='all'))
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude   Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN         NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN         NaN          NaN
# 2    Saltville, VA  United States  36.922223  -81.878056          NaN
# 3       EUREKA, CA  United States        NaN         NaN          NaN
# 4       Canton, OH  United States        NaN         NaN          NaN
#
#   Airport.Name  ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# 0          NaN  ...          Personal         NaN                  2.0
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Filtering aircrafts and events

# %% [markdown]
# We want to filter the dataset to include aircraft that the client is interested in an analysis of:
# - inspect relevant columns
# - figure out any reasonable imputations
# - filter the dataset

# %%
# Convert event dates to datetime objects to easily filter by year
df['Event.Date'] = pd.to_datetime(df['Event.Date'])

# Filter for accidents from 1983 onwards based on the 40-year max lifetime rule
df = df[df['Event.Date'].dt.year >= 1983]

# Keep only professional builds (filter out amateur built aircraft)
df = df[df['Amateur.Built'] == 'No']

# Check how many rows we have left after the initial filter
print(f"Remaining records: {df.shape[0]}")
# Out:
# Remaining records: 76960

# %% [markdown]
# ### Cleaning and constructing Key Measurables
#
# Injuries and robustness to destruction are a key interest point for the client. Clean and impute relevant columns and then create derived fields that best quantifies what the client wishes to track. **Use commenting or markdown to explain any cleaning assumptions as well as any derived columns you create.**

# %% [markdown]
# **Construct metric for fatal/serious injuries**
#
# *Hint:* Estimate the total number of passengers on each flight. The likelihood of serious / fatal injury can be estimated as a fraction from this.

# %%
# List of columns related to passenger counts
injury_cols = ['Total.Fatal.Injuries', 'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured']

# Fill NaNs with 0 so the addition works properly
df[injury_cols] = df[injury_cols].fillna(0)

# Calculate total people on board for the flight
df['Total_Passengers'] = df['Total.Fatal.Injuries'] + df['Total.Serious.Injuries'] + df['Total.Minor.Injuries'] + df['Total.Uninjured']

# We need to drop or filter out rows where total passengers is 0 to avoid dividing by zero
df = df[df['Total_Passengers'] > 0]

# Construct the metric: fraction of passengers who had fatal or serious injuries
df['Severe_Injury_Rate'] = (df['Total.Fatal.Injuries'] + df['Total.Serious.Injuries']) / df['Total_Passengers']

# %% [markdown]
# **Aircraft.Damage**
# - identify and execute any cleaning tasks
# - construct a derived column tracking whether an aircraft was destroyed or not.

# %%
print(df.columns.tolist())

# Clean up the text: make everything uppercase... (rest of your code)
# Out:
# ['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date', 'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code', 'Airport.Name', 'Injury.Severity', 'Aircraft.damage', 'Aircraft.Category', 'Registration.Number', 'Make', 'Model', 'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description', 'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries', 'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured', 'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status', 'Publication.Date', 'Total_Passengers', 'Severe_Injury_Rate']

# %% [markdown]
# ### Investigate the *Make* column
# - Identify cleaning tasks here
# - List cleaning tasks clearly in markdown
# - Execute the cleaning tasks
# - For your analysis, keep Makes with a reasonable number (you can put the threshold at 50 though lower could work as well)

# %%
# Standardize the text: uppercase and strip spaces
df['Make'] = df['Make'].astype(str).str.upper().str.strip()

# Count how many times each Make appears
make_counts = df['Make'].value_counts()

# Keep only the Makes that have 50 or more records
makes_to_keep = make_counts[make_counts >= 50].index
df = df[df['Make'].isin(makes_to_keep)]

# Quick check to see how many unique makers we have left
print(f"Number of unique makes remaining: {df['Make'].nunique()}")
# Out:
# Number of unique makes remaining: 90

# %% [markdown]
# ### Inspect Model column
# - Get rid of any NaNs.
# - Inspect the column and counts for each model/make. Are model labels unique to each make?
# - If not, create a derived column that is a unique identifier for a given plane type.

# %%
# Get rid of missing Model data
df = df.dropna(subset=['Model'])

# Standardize the Model text
df['Model'] = df['Model'].astype(str).str.upper().str.strip()

# Create a unique identifier combining Make and Model
df['Make_Model'] = df['Make'] + '_' + df['Model']

# Inspect the new column
display(df[['Make', 'Model', 'Make_Model']].head())
# Out:
#         Make       Model        Make_Model
# 3601  CESSNA        182P       CESSNA_182P
# 3602  CESSNA       182RG      CESSNA_182RG
# 3603  CESSNA        182P       CESSNA_182P
# 3604   PIPER  PA-28R-200  PIPER_PA-28R-200
# 3605  CESSNA         140        CESSNA_140

# %% [markdown]
# ### Cleaning other columns
# - there are other columns containing data that might be related to the outcome of an accident. We list a few here:
# - Engine.Type
# - Weather.Condition
# - Number.of.Engines
# - Purpose.of.flight
# - Broad.phase.of.flight
#
# Inspect and identify potential cleaning tasks in each of the above columns. Execute those cleaning tasks.
#
# **Note**: You do not necessarily need to impute or drop NaNs here.

# %%
# List of the extra columns to clean
other_cols = ['Engine.Type', 'Weather.Condition', 'Number.of.Engines', 'Purpose.of.flight', 'Broad.phase.of.flight']

for col in other_cols:
    # Check if the column actually exists to avoid KeyErrors
    if col in df.columns:
        # We only want to do string manipulation if the column is categorical (object type)
        if df[col].dtype == 'object':
            df[col] = df[col].astype(str).str.upper().str.strip()
            # If standardizing created string 'NAN's, convert them back to actual missing values
            df[col] = df[col].replace('NAN', np.nan)

# Quick look at the cleaned categories for Engine Type as an example
if 'Engine.Type' in df.columns:
    print(df['Engine.Type'].value_counts(dropna=False))
# Out:
# Engine.Type
# RECIPROCATING      54978
# NaN                 4585
# TURBO SHAFT         2983
# TURBO PROP          2782
# TURBO FAN           2042
# UNKNOWN             1435
# TURBO JET            538
# GEARED TURBOFAN        1
# LR                     1
# UNK                    1
# NONE                   1
# Name: count, dtype: int64

# %% [markdown]
# ### Column Removal
# - inspect the dataframe and drop any columns that have too many NaNs

# %%
# Calculate the percentage of missing values for each column
missing_percentages = df.isna().mean() * 100

# Set a threshold for dropping (e.g., 50% missing data)
threshold = 50

# Identify which columns exceed the threshold
cols_to_drop = missing_percentages[missing_percentages > threshold].index

# Drop those heavily missing columns from our dataframe
df = df.drop(columns=cols_to_drop)

# Print out what was dropped to keep track of our cleaning
print(f"Dropped {len(cols_to_drop)} columns missing more than {threshold}% of data:")
print(cols_to_drop.tolist())
# Out:
# Dropped 6 columns missing more than 50% of data:
# ['Latitude', 'Longitude', 'Aircraft.Category', 'FAR.Description', 'Schedule', 'Air.carrier']

# %% [markdown]
# ### Save DataFrame to csv
# - its generally useful to save data to file/server after its in a sufficiently cleaned or intermediate state
# - the data can then be loaded directly in another notebook for further analysis
# - this helps keep your notebooks and workflow readable, clean and modularized

# %%
# Save the cleaned dataframe to a new CSV file in the same directory
df.to_csv('cleaned_aviation_data.csv', index=False)

# Quick confirmation print out with the final shape of our clean data
print("Data successfully saved to 'cleaned_aviation_data.csv'!")
print(f"Final dataset shape ready for analysis: {df.shape}")
# Out:
# Data successfully saved to 'cleaned_aviation_data.csv'!
# Final dataset shape ready for analysis: (69347, 28)
